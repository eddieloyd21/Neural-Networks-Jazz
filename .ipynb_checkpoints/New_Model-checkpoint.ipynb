# %%
import glob
import numpy as np
import tensorflow as tf
from music21 import *
import random
from matplotlib import pyplot as plt
from fractions import Fraction

NUM_PIANO_KEYS = 88
A0_MIDI_OFFSET = 21

# %%
notes = []
offsets = []
durations = []
#glob.glob('midi_data/scales/**/*.mid', recursive=True)
#filenames = glob.glob('maestro-v3.0.0/**/*.mid*', recursive=True)
#maestro-v3.0.0\\2008\MIDI-Unprocessed_09_R1_2008_01-05_ORIG_MID--AUDIO_09_R1_2008_wav--3.midi
#G_major.mid
for file in ["G_major.mid"]:
    mid = converter.parse(file)
    notes_to_parse = None
    prev_offset = 0
          
    notes_to_parse = mid.flatten().notes
    
    for element in notes_to_parse:
        if isinstance(element, note.Note):
            arr = np.zeros(NUM_PIANO_KEYS)
            arr[element.pitch.midi - A0_MIDI_OFFSET] = 1
            notes.append(arr)
            
            durations.append(str(element.quarterLength))
            
            offsets.append(round(float(element.offset - prev_offset), 3))
            prev_offset = element.offset
            
        elif isinstance(element, chord.Chord):
            isFirstNote = True
            for n in element:
                arr = np.zeros(NUM_PIANO_KEYS)
                arr[n.pitch.midi - A0_MIDI_OFFSET] = 1
                notes.append(arr)
                
                durations.append(str(n.quarterLength))
                
                if isFirstNote:
                    offsets.append(round(float(element.offset - prev_offset), 3))
                    prev_offset = element.offset
                    isFirstNote = False
                else:
                    offsets.append(0)

notes = np.asarray(notes)
len(notes)
# Out:
# 352

# %%
duration_map = {duration: i for i, duration in enumerate(sorted(set(durations)))}
reverse_duration = {i: duration for i, duration in enumerate(sorted(set(durations)))}
if len(set(durations)) == 1:
    duration_map[str(float(list(duration_map.keys())[0]) * 2)] = len(duration_map)
    
temp = []
size = len(duration_map)
for duration in durations:
    arr = np.zeros(size)
    arr[duration_map[duration]] = 1
    temp.append(arr)
durations = np.asarray(temp)

# %%
offset_map = {offset: i for i, offset in enumerate(sorted(set(offsets)))}
reverse_offset = {i: offset for i, offset in enumerate(sorted(set(offsets)))}
temp = []
size = len(offset_map)
for offset in offsets:
    arr = np.zeros(size)
    arr[offset_map[offset]] = 1
    temp.append(arr)
offsets = np.asarray(temp)

# %%
train_notes = np.concatenate([notes, durations, offsets], axis = 1)

seq_length = 50
inputs = []
note_outputs = []
duration_outputs = []
offset_outputs = []
for i in range(len(notes) - seq_length):
    inputs.append(train_notes[i : i + seq_length])
    
    note_outputs.append(notes[i + seq_length])
    duration_outputs.append(durations[i + seq_length])
    offset_outputs.append(offsets[i + seq_length])
    
input_size = len(inputs)
inputs = np.asarray(inputs)
inputs.reshape(input_size, seq_length, len(train_notes[0]))

note_outputs = np.asarray(note_outputs)
duration_outputs = np.asarray(duration_outputs)
offset_outputs = np.asarray(offset_outputs)

# %%
input_shape = inputs[0].shape
learning_rate = 0.005

inp = tf.keras.Input(input_shape)
lstm = tf.keras.layers.LSTM(512)(inp)
drop = tf.keras.layers.Dropout(0.25)(lstm)
dense = tf.keras.layers.Dense(128)(drop)
out = {
    "pitch": tf.keras.layers.Dense(NUM_PIANO_KEYS, name = "pitch", activation = "softmax")(dense),
    "duration": tf.keras.layers.Dense(len(duration_map), name = "duration", activation = "softmax")(dense),
    "offset": tf.keras.layers.Dense(len(offset_map), name = "offset", activation = "softmax")(dense),
}

model = tf.keras.Model(inp, out)

model.compile(
    loss = "categorical_crossentropy",
    loss_weights = {
        'pitch': 1.0,
        'step': 1.0,
        'duration':1.0,
    },
    optimizer = tf.keras.optimizers.Adam(learning_rate = learning_rate),
    metrics = ["accuracy"]
)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 50, 92)]             0         []
#
#  lstm (LSTM)                 (None, 512)                  1239040   ['input_1[0][0]']
#
#  dropout (Dropout)           (None, 512)                  0         ['lstm[0][0]']
#
#  dense (Dense)               (None, 128)                  65664     ['dropout[0][0]']
#
#  duration (Dense)            (None, 2)                    258       ['dense[0][0]']
#
#  offset (Dense)              (None, 2)                    258       ['dense[0][0]']
#
#  pitch (Dense)               (None, 88)                   11352     ['dense[0][0]']
#
# ==================================================================================================
# Total params: 1316572 (5.02 MB)
# Trainable params: 1316572 (5.02 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# %%time
epochs = 25

history = model.fit(
    x = inputs,
    y = {"pitch": note_outputs, "duration": duration_outputs, "offset": offset_outputs},
    epochs = epochs,
    callbacks = tf.keras.callbacks.EarlyStopping(
        monitor = 'loss',
        patience = 5,
        verbose = 1,
        restore_best_weights = True),
    validation_split = 0.2
)
# Out:
# Epoch 1/25
# 8/8 [==============================] - 16s 943ms/step - loss: 4.4767 - duration_loss: 0.1948 - offset_loss: 0.1701 - pitch_loss: 4.1118 - duration_accuracy: 0.8672 - offset_accuracy: 1.0000 - pitch_accuracy: 0.0290 - val_loss: 3.6987 - val_duration_loss: 0.0000e+00 - val_offset_loss: 0.0000e+00 - val_pitch_loss: 3.6987 - val_duration_accuracy: 1.0000 - val_offset_accuracy: 1.0000 - val_pitch_accuracy: 0.0328
# Epoch 2/25
# 8/8 [==============================] - 5s 631ms/step - loss: 3.4200 - duration_loss: 2.9135e-07 - offset_loss: 4.4419e-07 - pitch_loss: 3.4200 - duration_accuracy: 1.0000 - offset_accuracy: 1.0000 - pitch_accuracy: 0.0456 - val_loss: 3.1489 - val_duration_loss: 7.4848e-07 - val_offset_loss: 9.0091e-07 - val_pitch_loss: 3.1489 - val_duration_accuracy: 1.0000 - val_offset_accuracy: 1.0000 - val_pitch_accuracy: 0.0984
# Epoch 3/25
# 8/8 [==============================] - 5s 660ms/step - loss: 3.2404 - duration_loss: 6.8795e-06 - offset_loss: 9.7716e-06 - pitch_loss: 3.2404 - duration_accuracy: 1.0000 - offset_accuracy: 1.0000 - pitch_accuracy: 0.0456 - val_loss: 3.0822 - val_duration_loss: 2.6255e-05 - val_offset_loss: 2.8991e-05 - val_pitch_loss: 3.0822 - val_duration_accuracy: 1.0000 - val_offset_accuracy: 1.0000 - val_pitch_accuracy: 0.0328
# Epoch 4/25
# 8/8 [==============================] - 5s 676ms/step - loss: 3.0650 - duration_loss: 6.7543e-05 - offset_loss: 3.8840e-05 - pitch_loss: 3.0648 - duration_accuracy: 1.0000 - offset_accuracy: 1.0000 - pitch_accuracy: 0.0747 - val_loss: 2.9459 - val_duration_loss: 3.1420e-05 - val_offset_loss: 1.9871e-05 - val_pitch_loss: 2.9458 - val_duration_accuracy: 1.0000 - val_offset_accuracy: 1.0000 - val_pitch_accuracy: 0.1148
# Epoch 5/25
# 8/8 [==============================] - 5s 679ms/step - loss: 2.9408 - duration_loss: 2.1065e-05 - offset_loss: 1.9961e-05 - pitch_loss: 2.9408 - duration_accuracy: 1.0000 - offset_accuracy: 1.0000 - pitch_accuracy: 0.1328 - val_loss: 2.7788 - val_duration_loss: 1.0881e-05 - val_offset_loss: 1.3742e-05 - val_pitch_loss: 2.7787 - val_duration_accuracy: 1.0000 - val_offset_accuracy: 1.0000 - val_pitch_accuracy: 0.3770
# Epoch 6/25
# 8/8 [==============================] - 5s 661ms/step - loss: 2.7074 - duration_loss: 1.8135e-05 - offset_loss: 1.7613e-05 - pitch_loss: 2.7074 - duration_accuracy: 1.0000 - offset_accuracy: 1.0000 - pitch_accuracy: 0.1909 - val_loss: 2.5702 - val_duration_loss: 3.0153e-05 - val_offset_loss: 2.5872e-05 - val_pitch_loss: 2.5702 - val_duration_accuracy: 1.0000 - val_offset_accuracy: 1.0000 - val_pitch_accuracy: 0.2623
# Epoch 7/25
# 8/8 [==============================] - 5s 669ms/step - loss: 2.3685 - duration_loss: 1.8770e-04 - offset_loss: 5.3029e-05 - pitch_loss: 2.3682 - duration_accuracy: 1.0000 - offset_accuracy: 1.0000 - pitch_accuracy: 0
plt.show()

# %%
plt.plot(history.epoch, history.history['duration_accuracy'], label='train duration accuracy')
plt.plot(history.epoch, history.history['val_duration_accuracy'], label='validation duration accuracy')

plt.plot(history.epoch, history.history['offset_accuracy'], label='train offset accuracy')
plt.plot(history.epoch, history.history['val_offset_accuracy'], label='validation offset accuracy')

plt.plot(history.epoch, history.history['pitch_accuracy'], label='train pitch accuracy')
plt.plot(history.epoch, history.history['val_pitch_accuracy'], label='validation pitch accuracy')

plt.legend()
plt.show()

# %%
num_notes = 100
seed_notes = inputs[0]
chord_builder = []
note_stream = []
offset = 0

for g in reversed(seed_notes):
    n = note.Note(np.argmax(g[:NUM_PIANO_KEYS]) + A0_MIDI_OFFSET)
    str_duration = reverse_duration[np.argmax(g[NUM_PIANO_KEYS : NUM_PIANO_KEYS + len(duration_map)])]
    try:
        n.quarterLength = float(str_duration)
    except:
        n.quarterLength = Fraction(str_duration)
    offset = reverse_offset[np.argmax(g[-1 * len(offset_map):])]
    if offset == 0:
        chord_builder.append(n)
    elif len(chord_builder) == 0:
        note_stream.append((n, offset))
    else:
        note_stream.append((chord.Chord(chord_builder), offset))
        chord_builder = []
if len(chord_builder) == 1:
    note_stream.append((chord_builder[0], 0))
elif len(chord_builder) > 1:
    note_stream.append((chord.Chord(chord_builder), 0))
note_stream.reverse()

# %%
seed_stream = stream.Stream()
previous_offset = 0
for n, off in note_stream:
    previous_offset += off
    seed_stream.insert(previous_offset, n)

# %%
generated_notes = []
for i in range(num_notes):
    new_note = model.predict(tf.expand_dims(seed_notes, 0))
    new_input = np.concatenate([new_note["pitch"], new_note["duration"], new_note["offset"]], axis = 1)
    generated_notes.append(new_note)
    seed_notes = np.delete(seed_notes, 0, axis = 0)
    seed_notes = np.append(seed_notes, new_input, axis = 0)
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 98ms/step

# %%
chord_builder = []
note_stream = []
offset = 0
for i in reversed(range(len(generated_notes))):
    g = generated_notes[i]
    n = note.Note(np.argmax(g["pitch"]) + A0_MIDI_OFFSET)
    try:
        n.quarterLength = float(reverse_duration[np.argmax(g["duration"])])
    except:
        n.quarterLength = Fraction(reverse_duration[np.argmax(g["duration"])])
    offset = reverse_offset[np.argmax(g["offset"])]
    if offset == 0:
        chord_builder.append(n)
    elif len(chord_builder) == 0:
        note_stream.append((n, offset))
    else:
        note_stream.append((chord.Chord(chord_builder), offset))
        chord_builder = []
if len(chord_builder) == 1:
    note_stream.append((chord_builder[0], 0))
elif len(chord_builder) > 1:
    note_stream.append((chord.Chord(chord_builder), 0))
note_stream.reverse()

# %%
s = stream.Stream()
previous_offset = 0
for n, off in note_stream:
    previous_offset += off
    s.insert(previous_offset, n)

# %%
seed_stream.write("midi", "seed.mid")
# Out:
# 'seed.mid'

# %%
seed_stream.show("midi")
# Out:
#                 <div id="midiPlayerDiv1329"></div>
#                 <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#                 <script>
#                 require.config({
#                     paths: {
#                         'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                     }
#                 });
#                 require(['music21'], function(music21) {
#                     mp = new music21.miditools.MidiPlayer();
#                     mp.addPlayer("#midiPlayerDiv1329");
#                     mp.base64Load("data:audio/midi;base64,...");
#                 });
#                 </script>

# %%
s.write("midi", "output.mid")
# Out:
# 'output.mid'

# %%
s.show("midi")
# Out:
#                 <div id="midiPlayerDiv2146"></div>
#                 <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#                 <script>
#                 require.config({
#                     paths: {
#                         'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                     }
#                 });
#                 require(['music21'], function(music21) {
#                     mp = new music21.miditools.MidiPlayer();
#                     mp.addPlayer("#midiPlayerDiv2146");
#                     mp.base64Load("data:audio/midi;base64,...");
#                 });
#                 </script>

# %%
seed_stream.show()

# %%
s.show()
