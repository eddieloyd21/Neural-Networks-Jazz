# %%
import glob
import os
import numpy as np
import tensorflow as tf
from music21 import *
import random
from matplotlib import pyplot as plt
from fractions import Fraction
import json

NUM_PIANO_KEYS = 88
A0_MIDI_OFFSET = 21

# %%
offset_map = dict()
with open('mappings/offset_map.txt') as f:
    for line in f:
        key, value = line.strip().split(":")
        offset_map[float(key)] = int(value)
with open('mappings/duration_map.txt') as json_file:
    duration_map = json.load(json_file)  
reverse_duration = dict()
with open('mappings/reverse_duration.txt') as f:
    for line in f:
        key, value = line.strip().split(":")
        reverse_duration[int(key)] = value
reverse_offset = dict()
with open('mappings/reverse_offset.txt') as f:
    for line in f:
        key, value = line.strip().split(":")
        reverse_offset[int(key)] = float(value)

# %%
notes = []
offsets = []
durations = []
#glob.glob('midi_data/scales/**/*.mid', recursive=True)
#filenames = glob.glob('maestro-v3.0.0/**/*.mid*', recursive=True)
#maestro-v3.0.0\\2008\MIDI-Unprocessed_09_R1_2008_01-05_ORIG_MID--AUDIO_09_R1_2008_wav--3.midi
#G_major.mid
count = 0
for file in glob.glob('rach_midi/*.mid*', recursive=True):
    mid = converter.parse(file)
    notes_to_parse = None
    prev_offset = 0
          
    notes_to_parse = mid.flatten().notes
    
    for element in notes_to_parse:
        if isinstance(element, note.Note):
            if str(element.quarterLength) in duration_map and round(float(element.offset - prev_offset), 3) in offset_map:
                
                arr = np.zeros(NUM_PIANO_KEYS)
                try:
                    arr[element.pitch.midi - A0_MIDI_OFFSET] = 1
                except IndexError:
                    os.remove(file)
                    break


                notes.append(arr)

                durations.append(str(element.quarterLength))

                offsets.append(round(float(element.offset - prev_offset), 3))
            else:
                count += 1
            prev_offset = element.offset
            
        elif isinstance(element, chord.Chord):
            isFirstNote = True
            for n in element:
                if str(element.quarterLength) in duration_map and round(float(element.offset - prev_offset), 3) in offset_map:
                    arr = np.zeros(NUM_PIANO_KEYS)
                    try:
                        arr[n.pitch.midi - A0_MIDI_OFFSET] = 1
                    except IndexError:
                        try:
                            os.remove(file)
                            break
                        except FileNotFoundError:
                            break

                    notes.append(arr)

                    durations.append(str(n.quarterLength))

                    if isFirstNote:
                        offsets.append(round(float(element.offset - prev_offset), 3))
                        isFirstNote = False
                    else:
                        offsets.append(float(0))
                else:
                    count += 1
                prev_offset = element.offset

notes = np.asarray(notes)
len(notes), count
# Out:
# (21627, 15)

# %%
temp = []
size = len(duration_map)
for duration in durations:
    arr = np.zeros(size)
    arr[duration_map[duration]] = 1
    temp.append(arr)
durations = np.asarray(temp)

# %%
temp = []
size = len(offset_map)
for offset in offsets:
    arr = np.zeros(size)
    try:
        arr[offset_map[offset]] = 1
    except IndexError:
        print(offset, offset_map[offset])
        print(arr[offset_map[offset]])
    temp.append(arr)
offsets = np.asarray(temp)

# %%
notes.shape
# Out:
# (21627, 88)

# %%
durations.shape
# Out:
# (21627, 50)

# %%
offsets.shape
# Out:
# (21627, 235)

# %%
train_notes = np.concatenate([notes, durations, offsets], axis = 1)

seq_length = 50
inputs = []
note_outputs = []
duration_outputs = []
offset_outputs = []
for i in range(len(notes) - seq_length):
    inputs.append(train_notes[i : i + seq_length])
    
    note_outputs.append(notes[i + seq_length])
    duration_outputs.append(durations[i + seq_length])
    offset_outputs.append(offsets[i + seq_length])
    
input_size = len(inputs)
inputs = np.asarray(inputs)
inputs.reshape(input_size, seq_length, len(train_notes[0]))

note_outputs = np.asarray(note_outputs)
duration_outputs = np.asarray(duration_outputs)
offset_outputs = np.asarray(offset_outputs)

# %%
input_shape = inputs[0].shape
learning_rate = 0.001

inp = tf.keras.Input(input_shape)
lstm = tf.keras.layers.LSTM(512)(inp)
drop = tf.keras.layers.Dropout(0.25)(lstm)
dense = tf.keras.layers.Dense(128)(drop)
out = {
    "pitch": tf.keras.layers.Dense(NUM_PIANO_KEYS, name = "pitch", activation = "softmax")(dense),
    "duration": tf.keras.layers.Dense(len(duration_map), name = "duration", activation = "softmax")(dense),
    "offset": tf.keras.layers.Dense(len(offset_map), name = "offset", activation = "softmax")(dense),
}

model = tf.keras.Model(inp, out)

model.compile(
    loss = "categorical_crossentropy",
    loss_weights = {
        'pitch': 1.0,
        'step': 1.0,
        'duration':1.0,
    },
    optimizer = tf.keras.optimizers.legacy.Adam(learning_rate = learning_rate),
    metrics = ["accuracy"]
)

model.load_weights("weights/jazznet")

model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_7 (InputLayer)        [(None, 50, 373)]            0         []
#
#  lstm_6 (LSTM)               (None, 512)                  1814528   ['input_7[0][0]']
#
#  dropout_6 (Dropout)         (None, 512)                  0         ['lstm_6[0][0]']
#
#  dense_6 (Dense)             (None, 128)                  65664     ['dropout_6[0][0]']
#
#  duration (Dense)            (None, 50)                   6450      ['dense_6[0][0]']
#
#  offset (Dense)              (None, 235)                  30315     ['dense_6[0][0]']
#
#  pitch (Dense)               (None, 88)                   11352     ['dense_6[0][0]']
#
# ==================================================================================================
# Total params: 1928309 (7.36 MB)
# Trainable params: 1928309 (7.36 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# %%time
epochs = 50

history = model.fit(
    x = inputs,
    y = {"pitch": note_outputs, "duration": duration_outputs, "offset": offset_outputs},
    epochs = epochs,
    callbacks = tf.keras.callbacks.EarlyStopping(
        monitor = 'loss',
        patience = 10,
        verbose = 1,
        restore_best_weights = True),
    validation_split = 0.2
)
# Out:
# Epoch 1/50
# 540/540 [==============================] - 209s 382ms/step - loss: 12.4631 - duration_loss: 1.4674 - offset_loss: 2.1441 - pitch_loss: 8.8516 - duration_accuracy: 0.8516 - offset_accuracy: 0.6307 - pitch_accuracy: 0.0582 - val_loss: 7.8721 - val_duration_loss: 0.6552 - val_offset_loss: 1.2492 - val_pitch_loss: 5.9677 - val_duration_accuracy: 0.8825 - val_offset_accuracy: 0.7030 - val_pitch_accuracy: 0.0373
# Epoch 2/50
# 540/540 [==============================] - 234s 433ms/step - loss: 6.3736 - duration_loss: 0.6937 - offset_loss: 1.1609 - pitch_loss: 4.5189 - duration_accuracy: 0.8723 - offset_accuracy: 0.6850 - pitch_accuracy: 0.0995 - val_loss: 6.5251 - val_duration_loss: 0.5626 - val_offset_loss: 1.1238 - val_pitch_loss: 4.8386 - val_duration_accuracy: 0.8920 - val_offset_accuracy: 0.6990 - val_pitch_accuracy: 0.0494
# Epoch 3/50
# Epoch 22/50
# 540/540 [==============================] - 228s 422ms/step - loss: 6.1117 - duration_loss: 0.6094 - offset_loss: 1.1591 - pitch_loss: 4.3431 - duration_accuracy: 0.8652 - offset_accuracy: 0.6610 - pitch_accuracy: 0.0386 - val_loss: 6.4213 - val_duration_loss: 0.5813 - val_offset_loss: 1.2406 - val_pitch_loss: 4.5995 - val_duration_accuracy: 0.8976 - val_offset_accuracy: 0.6821 - val_pitch_accuracy: 0.0183
# Epoch 23/50
# 540/540 [==============================] - 229s 424ms/step - loss: 5.9968 - duration_loss: 0.5928 - offset_loss: 1.1328 - pitch_loss: 4.2712 - duration_accuracy: 0.8711 - offset_accuracy: 0.6619 - pitch_accuracy: 0.0384 - val_loss: 6.2442 - val_duration_loss: 0.5766 - val_offset_loss: 1.1515 - val_pitch_loss: 4.5160 - val_duration_accuracy: 0.9029 - val_offset_accuracy: 0.6918 - val_pitch_accuracy: 0.0192
# Epoch 24/50
# 540/540 [==============================] - ETA: 0s - loss: 5.9243 - duration_loss: 0.5776 - offset_loss: 1.1101 - pitch_loss: 4.2367 - duration_accuracy: 0.8695 - offset_accuracy: 0.6694 - pitch_accuracy: 0.0392Restoring model weights from the end of the best epoch: 14.
# 540/540 [==============================] - 229s 424ms/step - loss: 5.9243 - duration_loss: 0.5776 - offset_loss: 1.1101 - pitch_loss: 4.2367 - duration_accuracy: 0.8695 - offset_accuracy: 0.6694 - pitch_accuracy: 0.0392 - val_loss: 6.1608 - val_duration_loss: 0.5764 - val_offset_loss: 1.1747 - val_pitch_loss: 4.4096 - val_duration_accuracy: 0.9069 - val_offset_accuracy: 0.6918 - val_pitch_accuracy: 0.0192
# Epoch 24: early stopping
# CPU times: total: 2h 33min 6s
# Wall time: 1h 32min 24s

# %%
model.save_weights("weights/rachmaninoff")
model.weights
# Out:
# [<tf.Variable 'lstm_6/lstm_cell/kernel:0' shape=(373, 2048) dtype=float32, numpy=
#  array([[-0.02549937, -0.02157745,  0.04676175, ..., -0.00208347,
#           0.0109541 ,  0.03197775],
#         [-1.026806  , -0.44804516,  1.3572658 , ...,  0.3118407 ,
#          -0.1568575 , -0.5805781 ],
#         [-0.02757075, -0.02471986, -0.00685724, ..., -0.04264772,
#           0.03959554, -0.04600886],
#         ...,
#         [-0.0039024 ,  0.00626381, -0.00258368, ...,  0.02822074,
#           0.01161296,  0.01594645],
#         [ 0.00987686,  0.04430768,  0.00975126, ...,  0.00523633,
#          -0.04047171, -0.0285727 ],
#         [ 0.01109227,  0.03107528,  0.03501086, ...,  0.01149857,
#           0.04023383,  0.03131195]], dtype=float32)>,
#  <tf.Variable 'lstm_6/lstm_cell/recurrent_kernel:0' shape=(512, 2048) dtype=float32, numpy=
#  array([[ 0.25507158,  1.7560447 , -0.44494322, ...,  0.33606562,
#           0.30688268,  0.18254437],
#         [-0.9269692 ,  1.7647542 ,  0.7250674 , ...,  1.8432189 ,
#           0.21475278, -0.08789342],
#         [-0.753069  , -0.33262163, -2.325162  , ...,  0.03440228,
#          -1.1851346 , -0.7435652 ],
#         ...,
#         [-0.27437738,  1.6662264 , -1.6182069 , ..., -0.14243327,
#          -0.4633049 ,  0.4716102 ],
#         [-0.4089295 ,  0.45434967, -0.5604646 , ..., -1.0890094 ,
#           0.2720633 , -2.4758537 ],
#         [-0.4675441 ,  0.45661893,  1.1536604 , ..., -0.11852258,
#           0.36185616,  1.0128224 ]], dtype=float32)>,
#  <tf.Variable 'lstm_6/lstm_cell/bias:0' shape=(2048,) dtype=float32, numpy=
#  array([-1.2251314 , -0.5404044 , -0.7061781 , ..., -1.1891277 ,
#         -1.1948708 , -0.92417747], dtype=float32)>,
#  <tf.Variable 'dense_6/kernel:0' shape=(512, 128) dtype=float32, numpy=
#  array([[ 0.28519395, -0.15552083,  0.07312481, ..., -0.63690525,
#           0.25943714,  0.31042668],
#         [ 0.44257566,  0.29865715,  0.23390305, ..., -1.2850697 ,
#          -1.3621414 , -1.1062862 ],
#         [-0.46503153,  0.10461462,  0.6972064 , ..., -0.16427855,
#          -0.426956  ,  0.7815602 ],
#         ...,
#         [-0.5932859 , -0.88447505,  0.50872165, ..., -0.7070125 ,
#          -0.5580838 ,  1.2900784 ],
#         [-0.21009827, -0.5860017 , -0.60697424, ...,  0.2114526 ,
#           0.04150344, -0.06597015],
#         [ 1.1764672 , -0.53883344, -0.18470311, ..., -0.29141775,
#          -0.05958224,  0.0216474 ]], dtype=float32)>,
#  <tf.Variable 'dense_6/bias:0' shape=(128,) dtype=float32, numpy=
#  array([-0.4872982 ,  0.10282979, -0.17882527, -0.22392257, -0.07545478,
#          0.03555806, -0.0626916 , -0.03620761, -0.01507044, -0.01797063,
#         -0.20159239, -0.25088552,  0.11020151,  0.06429119, -0.43502784,
#          0.8308853 ,  0.16071492, -0.0047344 ,  0.21347232,  0.00999288,
#         -0.1471666 ,  0.03996928, -0.5070575 , -0.10091968,  0.03808583,
#         -0.03614727, -0.26066494, -0.19541167, -0.04065992, -0.37591833,
#          0.09770075, -0.05895692,  0.15681009,  0.3026678 , -0.45126492,
#          0.18472785,  0.07541484, -0.19940199,  0.26413548, -0.15251426,
#          0.17976534, -0.10991757,  0.00590075, -0.07836914,  0.0305017 ,
#         -0.06254917,  0.03233463,  0.05609666,  0.10021567, -0.15848655,
#          0.10986546,  0.10835128,  0.15770242,  0.04413817, -0.16461064,
#         -0.08708274, -0.24403155, -0.40914828,  0.09502476,  0.02898435,
#          0.04182466, -0.31006342, -0.04335855,  0.05343397, -0.2630385 ,
#          0.0816474 , -0.1692754 , -0.27405384,  0.45782343,  0.41529605,
#          0.12814628, -0.29805952,  0.42978302, -0.13994178, -0.13138478,
#         -0.0683589 , -0.15594767,  0.0500411 , -0.21832393, -0.15966931,
#          0.00084961, -0.24141075,  0.03812   , -0.13624327, -0.44620484,
#          0.05067445,  0.13799734,  0.01768588, -0.08399572,  0.21259898,
#         -0.12873247, -0.2611273 , -0.08545817,  0.01844574,  0.3057053 ,
#          0.04214074,  0.03676494,  0.10952579, -0.08071028, -0.09319383,
#         -0.31436357, -0.09606097,  0.04235037, -0.36979   , -0.08324359,
#         -0.03984341, -0.12168583, -0.25278452,  0.04366861, -0.05779433,
#         -0.10822386, -0.07000888, -0.10217734, -0.3833512 ,  0.09381525,
#         -0.17006394, -0.16189717,  0.09236977, -0.03217649, -0.02500414,
#          0.03905978, -0.05904885,  0.3012914 , -0.4247835 ,  0.00492764,
#          0.14966951,  0.10336541, -0.71675503], dtype=float32)>,
#  <tf.Variable 'duration/kernel:0' shape=(128, 50) dtype=float32, numpy=
#  array([[ 1.0527903e+00, -4.5605409e-01,  9.0754375e-02, ...,
#           3.9529619e-01,  5.3731036e-01,  4.7255746e-01],
#         [ 8.0648623e-02,  4.5621544e-01,  1.6817501e-01, ...,
#           4.6245882e-01,  1.7117305e-01,  3.2146206e-01],
#         [ 2.4976674e-02, -1.3172521e-01, -4.3534034e-01, ...,
#          -7.2179848e-01, -2.2017068e-01, -3.7326691e-01],
#         ...,
#         [-1.9909805e-03, -2.8953105e-02,  3.2686517e-01, ...,
#          -2.7359343e-01, -1.4359003e-01,  1.0837173e-01],
#         [-4.2753321e-01,  2.5857592e-01, -9.8224036e-02, ...,
#          -4.7602406e-01, -8.0452114e-01, -3.8720128e-01],
#         [-4.0064292e+00, -2.8567920e+00, -3.7696848e+00, ...,
#          -4.5403070e+00, -3.4472215e+00, -3.9734249e+00]], dtype=float32)>,
#  <tf.Variable 'duration/bias:0' shape=(50,) dtype=float32, numpy=
#  array([ -8.4194975,  -4.6238017,  -7.2298784,  -6.4691615,   8.749117 ,
#          -7.9585977,  -7.210888 ,  -9.350309 ,  -8.076897 ,  -6.946421 ,
#          -9.393948 ,  -8.806523 ,  -8.203786 ,  -8.70209  ,  -8.285194 ,
#          -8.70254  ,  -9.107775 ,  -9.585767 ,  -8.3326645,  -8.433368 ,
#          -9.097192 ,  -7.9329906,  -8.808455 ,  -8.665887 ,  -8.044076 ,
#          -6.89474  ,  -9.100662 , -10.373231 ,  -9.468131 , -10.002088 ,
#          -8.651353 ,  -8.638787 ,  -8.768846 ,  -7.945264 ,  -8.108477 ,
#         -10.029223 ,  -8.212396 ,  -8.8635235,  -9.077212 ,  -8.431142 ,
#          -9.355102 ,  -8.677471 ,  -8.500842 ,  -8.645199 ,  -8.04229  ,
#          -9.209394 ,  -9.0589905,  -8.436042 ,  -9.083747 ,  -9.692479 ],
#        dtype=float32)>,
#  <tf.Variable 'offset/kernel:0' shape=(128, 235) dtype=float32, numpy=
#  array([[-0.38191044,  0.07499152, -0.39875022, ...,  1.5615208 ,
#           1.4409375 ,  1.8184413 ],
#         [ 0.451334  ,  0.14550464,  0.90063393, ..., -0.20322901,
#          -0.38493583,  0.00986822],
#         [-0.29840302, -0.17413011, -0.37744302, ...,  0.30420646,
#         -1.24257222e-01, -8.27589557e-02, -6.36824369e-02, -7.61862621e-02,
#          1.50720030e-01, -1.42614856e-01,  2.58220166e-01,  3.26356739e-01,
#          2.70876765e-01,  1.38407484e-01, -1.59819290e-01, -1.32570446e-01,
#          3.97501558e-01,  3.19436759e-01, -1.61221430e-01,  1.51023149e-01,
#          1.65013716e-01,  2.72071093e-01,  3.17327976e-01,  2.20258474e-01,
#          2.22797453e-01,  2.90286571e-01, -3.44088614e-01,  2.31185168e-01,
#          2.57344902e-01,  4.82428253e-01,  3.50022733e-01,  1.65618524e-01,
#          2.55892903e-01,  3.33290786e-01,  2.79620409e-01,  1.40228271e-01,
#          2.07355525e-02,  4.72988993e-01, -2.83770949e-01, -1.95643306e-01,
#         -7.60741755e-02,  3.85087132e-01,  1.09351352e-01,  8.79919976e-02,
#          3.11839700e-01,  1.54788699e-03,  2.85096139e-01,  1.37768447e-01,
#          8.98939893e-02,  1.86099201e-01, -4.41614270e-01,  1.36401147e-01,
#          1.57108709e-01,  7.23876208e-02,  2.10195631e-01, -1.03576936e-01,
#          5.24305701e-01, -3.38904299e-02, -2.63714850e-01, -1.51958629e-01,
#         -3.18331838e-01,  5.12549520e-01,  2.26437822e-02, -2.91709274e-01,
#          2.59193201e-02, -1.08371139e-01, -2.74695069e-01, -9.12004709e-01,
#         -8.01770449e-01, -1.83843887e+00, -1.64005923e+00, -6.94536030e-01,
#         -2.10380220e+00, -1.31239271e+00, -2.30568576e+00, -2.76608109e+00],
#        dtype=float32)>]

# %%
plt.plot(history.epoch, history.history['loss'], label='total train loss')
plt.plot(history.epoch, history.history['val_loss'], label='total validation loss')
plt.legend()
plt.show()

# %%
plt.plot(history.epoch, history.history['duration_accuracy'], label='train duration accuracy')
plt.plot(history.epoch, history.history['val_duration_accuracy'], label='validation duration accuracy')

plt.plot(history.epoch, history.history['offset_accuracy'], label='train offset accuracy')
plt.plot(history.epoch, history.history['val_offset_accuracy'], label='validation offset accuracy')

plt.plot(history.epoch, history.history['pitch_accuracy'], label='train pitch accuracy')
plt.plot(history.epoch, history.history['val_pitch_accuracy'], label='validation pitch accuracy')

plt.legend()
plt.show()

# %%
num_notes = 100
seed_notes = inputs[0]
chord_builder = []
note_stream = []
offset = 0

for g in reversed(seed_notes):
    n = note.Note(np.argmax(g[:NUM_PIANO_KEYS]) + A0_MIDI_OFFSET)
    str_duration = reverse_duration[np.argmax(g[NUM_PIANO_KEYS : NUM_PIANO_KEYS + len(duration_map)])]
    try:
        n.quarterLength = float(str_duration)
    except:
        n.quarterLength = Fraction(str_duration)
    offset = reverse_offset[np.argmax(g[-1 * len(offset_map):])]
    if offset == 0:
        chord_builder.append(n)
    elif len(chord_builder) == 0:
        note_stream.append((n, offset))
    else:
        note_stream.append((chord.Chord(chord_builder), offset))
        chord_builder = []
if len(chord_builder) == 1:
    note_stream.append((chord_builder[0], 0))
elif len(chord_builder) > 1:
    note_stream.append((chord.Chord(chord_builder), 0))
note_stream.reverse()

# %%
seed_stream = stream.Stream()
previous_offset = 0
for n, off in note_stream:
    previous_offset += off
    seed_stream.insert(previous_offset, n)

# %%
generated_notes = []
for i in range(num_notes):
    new_note = model.predict(tf.expand_dims(seed_notes, 0))
    new_input = np.concatenate([new_note["pitch"], new_note["duration"], new_note["offset"]], axis = 1)
    generated_notes.append(new_note)
    seed_notes = np.delete(seed_notes, 0, axis = 0)
    seed_notes = np.append(seed_notes, new_input, axis = 0)
# Out:
# 1/1 [==============================] - 0s 474ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 44ms/step

# %%
chord_builder = []
note_stream = []
offset = 0
for i in reversed(range(len(generated_notes))):
    g = generated_notes[i]
    n = note.Note(np.argmax(g["pitch"]) + A0_MIDI_OFFSET)
    try:
        n.quarterLength = float(reverse_duration[np.argmax(g["duration"])])
    except:
        n.quarterLength = Fraction(reverse_duration[np.argmax(g["duration"])])
    offset = reverse_offset[np.argmax(g["offset"])]
    if offset == 0:
        chord_builder.append(n)
    elif len(chord_builder) == 0:
        note_stream.append((n, offset))
    else:
        note_stream.append((chord.Chord(chord_builder), offset))
        chord_builder = []
if len(chord_builder) == 1:
    note_stream.append((chord_builder[0], 0))
elif len(chord_builder) > 1:
    note_stream.append((chord.Chord(chord_builder), 0))
note_stream.reverse()

# %%
s = stream.Stream()
previous_offset = 0
for n, off in note_stream:
    previous_offset += off
    s.insert(previous_offset, n)

# %%
seed_stream.write("midi", "seed.mid")
# Out:
# 'seed.mid'

# %%
seed_stream.show("midi")
# Out:
#                 <div id="midiPlayerDiv1079217"></div>
#                 <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#                 <script>
#                 require.config({
#                     paths: {
#                         'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                     }
#                 });
#                 require(['music21'], function(music21) {
#                     mp = new music21.miditools.MidiPlayer();
#                     mp.addPlayer("#midiPlayerDiv1079217");
#                     mp.base64Load("data:audio/midi;base64,...");
#                 });
#                 </script>

# %%
s.write("midi", "output.mid")
# Out:
# 'output.mid'

# %%
s.show("midi")
# Out:
#                 <div id="midiPlayerDiv1079242"></div>
#                 <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#                 <script>
#                 require.config({
#                     paths: {
#                         'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                     }
#                 });
#                 require(['music21'], function(music21) {
#                     mp = new music21.miditools.MidiPlayer();
#                     mp.addPlayer("#midiPlayerDiv1079242");
#                     mp.base64Load("data:audio/midi;base64,...");
#                 });
#                 </script>

# %%
seed_stream.show()
# Out:
# ---------------------------------------------------------------------------
# MusicXMLExportException                   Traceback (most recent call last)
# Cell In [50], line 1
# ----> 1 seed_stream.show()
#
# File ~\miniconda3\lib\site-packages\music21\stream\base.py:397, in Stream.show(self, fmt, app, **keywords)
#     395 if self.isSorted is False and self.autoSort:
#     396     self.sort()
# --> 397 return super().show(fmt=fmt, app=app, **keywords)
#
# File ~\miniconda3\lib\site-packages\music21\base.py:2888, in Music21Object.show(self, fmt, app, **keywords)
#    2886 scClass = common.findSubConverterForFormat(regularizedConverterFormat)
#    2887 formatWriter = scClass()
# -> 2888 return formatWriter.show(self,
#    2889                          regularizedConverterFormat,
#    2890                          app=app,
#    2891                          subformats=subformats,
#    2892                          **keywords)
#
# File ~\miniconda3\lib\site-packages\music21\converter\subConverters.py:395, in ConverterIPython.show(self, obj, fmt, app, subformats, **keywords)
#     392     scores = list(obj.scores)
#     394 for s in scores:
# --> 395     fp = helperSubConverter.write(s,
#     396                                   helperFormat,
#     397                                   subformats=helperSubformats,
#     398                                   **keywords
#     399                                   )
#     401     if helperSubformats[0] == 'png':
#     402         if not str(environLocal['musescoreDirectPNGPath']).startswith('/skip'):
#
# File ~\miniconda3\lib\site-packages\music21\converter\subConverters.py:1123, in ConverterMusicXML.write(self, obj, fmt, fp, subformats, makeNotation, compress, **keywords)
#    1121 generalExporter = m21ToXml.GeneralObjectExporter(obj)
#    1122 generalExporter.makeNotation = makeNotation
# -> 1123 dataBytes = generalExporter.parse()
#    1125 writeDataStreamFp = fp
#    1126 if fp is not None and subformats:  # could be empty list
#
# File ~\miniconda3\lib\site-packages\music21\musicxml\m21ToXml.py:432, in GeneralObjectExporter.parse(self, obj)
#     430 if self.makeNotation:
#     431     outObj = self.fromGeneralObject(obj)
# --> 432     return self.parseWellformedObject(outObj)
#     433 else:
#     434     if not isinstance(obj, stream.Score):
#
# File ~\miniconda3\lib\site-packages\music21\musicxml\m21ToXml.py:448, in GeneralObjectExporter.parseWellformedObject(self, sc)
#     439 '''
#     440 Parse an object that has already gone through the
#     441 `.fromGeneralObject` conversion, which has produced a copy with
#    (...)
#     445 Returns bytes.
#     446 '''
#     447 scoreExporter = ScoreExporter(sc, makeNotation=self.makeNotation)
# --> 448 scoreExporter.parse()
#     449 return scoreExporter.asBytes()
#
# File ~\miniconda3\lib\site-packages\music21\musicxml\m21ToXml.py:1519, in ScoreExporter.parse(self)
#    1517     self.setPartExporterStaffGroups()
#    1518     self.renumberVoicesWithinStaffGroups()
# -> 1519     self.parsePartlikeScore()
#    1520 else:
#    1521     self.parseFlatScore()
#
# File ~\miniconda3\lib\site-packages\music21\musicxml\m21ToXml.py:1705, in ScoreExporter.parsePartlikeScore(self)
#    1703     self._populatePartExporterList()
#    1704 for part_ex in self.partExporterList:
# -> 1705     part_ex.parse()
#
# File ~\miniconda3\lib\site-packages\music21\musicxml\m21ToXml.py:2742, in PartExporter.parse(self)
#    2740             e.partName = self.stream.partName
#    2741         # else: could be a Score without parts (flat)
# -> 2742         raise e
#    2743     self.xmlRoot.append(mxMeasure)
#    2745 return self.xmlRoot
#
# File ~\miniconda3\lib\site-packages\music21\musicxml\m21ToXml.py:2736, in PartExporter.parse(self)
#    2734 measureExporter.spannerBundle = self.spannerBundle
#    2735 try:
# -> 2736     mxMeasure = measureExporter.parse()
#    2737 except MusicXMLExportException as e:
#    2738     e.measureNumber = str(m.number)
#
# File ~\miniconda3\lib\site-packages\music21\musicxml\m21ToXml.py:3174, in MeasureExporter.parse(self)
#    3172 self.setLeftBarline()
#    3173 # BIG ONE
# -> 3174 self.mainElementsParse()
#    3175 # continue
#    3176 self.setRightBarline()
#
# File ~\miniconda3\lib\site-packages\music21\musicxml\m21ToXml.py:3202, in MeasureExporter.mainElementsParse(self)
#    3199     backupAfterwards = True
#    3201 # Assumes voices are flat...
# -> 3202 self.parseFlatElements(v, backupAfterwards=backupAfterwards)
#
# File ~\miniconda3\lib\site-packages\music21\musicxml\m21ToXml.py:3266, in MeasureExporter.parseFlatElements(self, m, backupAfterwards)
#    3262         if n.isRest and n.style.hideObjectOnPrint and n.duration.type == 'inexpressible':
#    3263             # Prefer a gap in stream, to be filled with a <forward> tag by
#    3264             # fill_gap_with_forward_tag() rather than raising exceptions
#    3265             continue
# -> 3266         self.parseOneElement(n)
#    3268 if backupAfterwards:
#    3269     # return to the beginning of the measure.
#    3270     amountToBackup = round(divisions * self.offsetInMeasure)
#
# File ~\miniconda3\lib\site-packages\music21\musicxml\m21ToXml.py:3313, in MeasureExporter.parseOneElement(self, obj)
#    3311 meth = getattr(self, methName)
#    3312 for o in objList:
# -> 3313     meth(o)
#    3314 parsedObject = True
#    3315 break
#
# File ~\miniconda3\lib\site-packages\music21\musicxml\m21ToXml.py:4111, in MeasureExporter.restToXml(self, r)
#    4024 def restToXml(self, r: note.Rest):
#    4025     # noinspection PyShadowingNames
#    4026     '''
#    4027     Convert a Rest object to a <note> with a <rest> tag underneath it.
#    4028
#    (...)
#    4109     </note>
#    4110     '''
# -> 4111     mxNote = self.noteToXml(r)
#    4112     mxRestTag = mxNote.find('rest')
#    4113     if mxRestTag is None:
#
# File ~\miniconda3\lib\site-packages\music21\musicxml\m21ToXml.py:3886, in MeasureExporter.noteToXml(self, n, noteIndexInChord, chordParent)
#    3884 else:
#    3885     try:
# -> 3886         mxType.text = typeToMusicXMLType(d.type)
#    3887     except MusicXMLExportException:
#    3888         if isinstance(n, note.Rest) and helpers.isFullMeasureRest(n):
#    3889             # type will be removed in xmlToRest()
#
# File ~\miniconda3\lib\site-packages\music21\musicxml\m21ToXml.py:102, in typeToMusicXMLType(value)
#      99     raise MusicXMLExportException(
#     100         'Cannot convert "duplex-maxima" duration to MusicXML (too long).')
#     101 elif value == 'inexpressible':
# --> 102     raise MusicXMLExportException('Cannot convert inexpressible durations to MusicXML.')
#     103 elif value == 'complex':
#     104     raise MusicXMLExportException(
#     105         'Cannot convert complex durations to MusicXML. '
#     106         + 'Try exporting with makeNotation=True or manually running splitAtDurations()')
#
# MusicXMLExportException: In part (None), measure (4): Cannot convert inexpressible durations to MusicXML.

# %%
s.show()

# %%
freq = dict()
for offset in offsets:
    o = reverse_offset[np.argmax(offset)]
    if o not in freq:
        freq[o] = 0
    freq[o] += 1

# %%
freq
# Out:
# {2.0: 30,
#  0.0: 5623,
#  0.333: 4843,
#  1.667: 51,
#  1.25: 180,
#  0.25: 7967,
#  0.5: 3794,
#  0.083: 859,
#  1.417: 50,
#  0.583: 591,
#  1.167: 32,
#  3.25: 8,
#  0.167: 921,
#  1.333: 116,
#  0.667: 993,
#  1.5: 160,
#  1.0: 369,
#  0.417: 1396,
#  1.083: 48,
#  0.75: 1058,
#  0.917: 123,
#  9.0: 1,
#  1.583: 32,
#  0.833: 124,
#  4.25: 3,
#  3.333: 3,
#  3.75: 7,
#  1.75: 39,
#  6.833: 2,
#  2.083: 3,
#  2.25: 14,
#  7.25: 1,
#  17.5: 1,
#  5.75: 3,
#  2.583: 5,
#  4.5: 1,
#  10.333: 2,
#  1.833: 5,
#  2.333: 14,
#  4.0: 17,
#  6.5: 2,
#  9.25: 1,
#  17.0: 1,
#  3.0: 14,
#  2.75: 10,
#  6.0: 4,
#  5.25: 3,
#  4.75: 1,
#  3.5: 9,
#  2.833: 2,
#  8.0: 1,
#  13.0: 2,
#  8.25: 2,
#  21.333: 1,
#  2.5: 16,
#  7.0: 2,
#  7.5: 1,
#  3.167: 3,
#  4.917: 1,
#  7.75: 2,
#  4.333: 2,
#  4.417: 1,
#  6.583: 2,
#  3.667: 6,
#  3.083: 3,
#  3.917: 3,
#  2.917: 1,
#  2.667: 6,
#  2.417: 1,
#  5.083: 1,
#  2.167: 2,
#  1.917: 4,
#  8.083: 1,
#  15.75: 1,
#  4.667: 1,
#  8.5: 1,
#  10.0: 1,
#  25.5: 1,
#  14.5: 1,
#  12.0: 1,
#  5.333: 1,
#  9.5: 1,
#  7.583: 1,
#  8.75: 1,
#  9.083: 1}
